# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fresno_dem_1.csv')
df1
# Out:
#           latitude   longitude  elevation
# 0        36.000000 -119.000000       2186
# 1        36.000000 -118.999722       2178
# 2        36.000000 -118.999444       2168
# 3        36.000000 -118.999167       2162
# 4        36.000000 -118.998889       2154
# ...            ...         ...        ...
# 1048570  36.080833 -118.811389       2225
# 1048571  36.080833 -118.811111       2228
# 1048572  36.080833 -118.810833       2230
# 1048573  36.080833 -118.810556       2234
# 1048574  36.080833 -118.810278       2235
#
# [1048575 rows x 3 columns]

# %%
import pandas as pd

df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fresno_dem_2.csv')
print(df2.head())
# Out:
#    latitude   longitude  elevation
# 0      37.0 -120.000000       1697
# 1      37.0 -119.999722       1691
# 2      37.0 -119.999444       1684
# 3      37.0 -119.999167       1680
# 4      37.0 -119.998889       1677

# %%
import pandas as pd

df3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fresno_dem_3.csv')
print(df3.head())
# Out:
#    latitude   longitude  elevation
# 0      37.0 -119.000000       1948
# 1      37.0 -118.999722       1948
# 2      37.0 -118.999444       1948
# 3      37.0 -118.999167       1948
# 4      37.0 -118.998889       1948

# %%
import pandas as pd

df4 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fresno_dem_4.csv')
print(df4.head())
# Out:
#    latitude   longitude  elevation
# 0      36.0 -121.000000        180
# 1      36.0 -120.999722        180
# 2      36.0 -120.999444        181
# 3      36.0 -120.999167        177
# 4      36.0 -120.998889        175

# %%
import pandas as pd

df5 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fresno_dem_5.csv')
print(df5.head())
# Out:
#    latitude   longitude  elevation
# 0      36.0 -120.000000         95
# 1      36.0 -119.999722         96
# 2      36.0 -119.999444         95
# 3      36.0 -119.999167         94
# 4      36.0 -119.998889         94

# %%
import pandas as pd

# Assuming df1 is your DataFrame with elevation column
# Convert elevation column to integer type to remove decimal part
df1['elevation'] = df1['elevation'].astype(int)

# Display the DataFrame to verify changes
print(df1.head())
# Out:
#    latitude   longitude  elevation
# 0      36.0 -119.000000       2186
# 1      36.0 -118.999722       2178
# 2      36.0 -118.999444       2168
# 3      36.0 -118.999167       2162
# 4      36.0 -118.998889       2154

# %%
# Assuming df1 is your DataFrame with longitude column
df1['longitude'] = df1['longitude'].round(4)

# Display the DataFrame to verify changes
print(df1.head())
# Out:
#    latitude  longitude  elevation
# 0      36.0  -119.0000       2186
# 1      36.0  -118.9997       2178
# 2      36.0  -118.9994       2168
# 3      36.0  -118.9992       2162
# 4      36.0  -118.9989       2154

# %%
# Assuming df1 is your DataFrame with longitude column
df2['longitude'] = df2['longitude'].round(4)

# Display the DataFrame to verify changes
print(df2.head())
# Out:
#    latitude  longitude  elevation
# 0      37.0  -120.0000       1697
# 1      37.0  -119.9997       1691
# 2      37.0  -119.9994       1684
# 3      37.0  -119.9992       1680
# 4      37.0  -119.9989       1677

# %%
# Assuming df1 is your DataFrame with longitude column
df3['longitude'] = df3['longitude'].round(4)

# Display the DataFrame to verify changes
print(df3.head())
# Out:
#    latitude  longitude  elevation
# 0      37.0  -119.0000       1948
# 1      37.0  -118.9997       1948
# 2      37.0  -118.9994       1948
# 3      37.0  -118.9992       1948
# 4      37.0  -118.9989       1948

# %%
# Assuming df1 is your DataFrame with longitude column
df4['longitude'] = df4['longitude'].round(4)

# Display the DataFrame to verify changes
print(df4.head())
# Out:
#    latitude  longitude  elevation
# 0      36.0  -121.0000        180
# 1      36.0  -120.9997        180
# 2      36.0  -120.9994        181
# 3      36.0  -120.9992        177
# 4      36.0  -120.9989        175

# %%
# Assuming df1 is your DataFrame with longitude column
df5['longitude'] = df5['longitude'].round(4)

# Display the DataFrame to verify changes
print(df5.head())
# Out:
#    latitude  longitude  elevation
# 0      36.0  -120.0000         95
# 1      36.0  -119.9997         96
# 2      36.0  -119.9994         95
# 3      36.0  -119.9992         94
# 4      36.0  -119.9989         94

# %%
df1['latitude'] = df1['latitude'].map('{:.4f}'.format)
df1
# Out:
#         latitude  longitude  elevation
# 0        36.0000  -119.0000       2186
# 1        36.0000  -118.9997       2178
# 2        36.0000  -118.9994       2168
# 3        36.0000  -118.9992       2162
# 4        36.0000  -118.9989       2154
# ...          ...        ...        ...
# 1048570  36.0808  -118.8114       2225
# 1048571  36.0808  -118.8111       2228
# 1048572  36.0808  -118.8108       2230
# 1048573  36.0808  -118.8106       2234
# 1048574  36.0808  -118.8103       2235
#
# [1048575 rows x 3 columns]

# %%
df2['latitude'] = df2['latitude'].map('{:.4f}'.format)
df2
# Out:
#         latitude  longitude  elevation
# 0        37.0000  -120.0000       1697
# 1        37.0000  -119.9997       1691
# 2        37.0000  -119.9994       1684
# 3        37.0000  -119.9992       1680
# 4        37.0000  -119.9989       1677
# ...          ...        ...        ...
# 1048570  37.0808  -119.8114       1149
# 1048571  37.0808  -119.8111       1154
# 1048572  37.0808  -119.8108       1163
# 1048573  37.0808  -119.8106       1173
# 1048574  37.0808  -119.8103       1181
#
# [1048575 rows x 3 columns]

# %%
df3['latitude'] = df3['latitude'].map('{:.4f}'.format)
df3
# Out:
#         latitude  longitude  elevation
# 0        37.0000  -119.0000       1948
# 1        37.0000  -118.9997       1948
# 2        37.0000  -118.9994       1948
# 3        37.0000  -118.9992       1948
# 4        37.0000  -118.9989       1948
# ...          ...        ...        ...
# 1048570  37.0808  -118.8114       2252
# 1048571  37.0808  -118.8111       2251
# 1048572  37.0808  -118.8108       2250
# 1048573  37.0808  -118.8106       2250
# 1048574  37.0808  -118.8103       2251
#
# [1048575 rows x 3 columns]

# %%
df4['latitude'] = df4['latitude'].map('{:.4f}'.format)
df4
# Out:
#         latitude  longitude  elevation
# 0        36.0000  -121.0000        180
# 1        36.0000  -120.9997        180
# 2        36.0000  -120.9994        181
# 3        36.0000  -120.9992        177
# 4        36.0000  -120.9989        175
# ...          ...        ...        ...
# 1048570  36.0808  -120.8114         72
# 1048571  36.0808  -120.8111         71
# 1048572  36.0808  -120.8108         70
# 1048573  36.0808  -120.8106         69
# 1048574  36.0808  -120.8103         69
#
# [1048575 rows x 3 columns]

# %%
df5['latitude'] = df5['latitude'].map('{:.4f}'.format)
df5
# Out:
#         latitude  longitude  elevation
# 0        36.0000  -120.0000         95
# 1        36.0000  -119.9997         96
# 2        36.0000  -119.9994         95
# 3        36.0000  -119.9992         94
# 4        36.0000  -119.9989         94
# ...          ...        ...        ...
# 1048570  36.0808  -119.8114        114
# 1048571  36.0808  -119.8111        114
# 1048572  36.0808  -119.8108        117
# 1048573  36.0808  -119.8106        117
# 1048574  36.0808  -119.8103        115
#
# [1048575 rows x 3 columns]

# %%
duplicates1 = df1.duplicated()

num_duplicates1 = duplicates1.sum()

print(f'Number of duplicate rows in df1: {num_duplicates1}')
# Out:
# Number of duplicate rows in df1: 0

# %%
duplicates2 = df2.duplicated()

num_duplicates2 = duplicates2.sum()

print(f'Number of duplicate rows in df2: {num_duplicates2}')
# Out:
# Number of duplicate rows in df2: 0

# %%
duplicates3 = df3.duplicated()

num_duplicates3 = duplicates3.sum()

print(f'Number of duplicate rows in df3: {num_duplicates3}')
# Out:
# Number of duplicate rows in df3: 0

# %%
duplicates4 = df4.duplicated()

num_duplicates4 = duplicates4.sum()

print(f'Number of duplicate rows in df4: {num_duplicates4}')
# Out:
# Number of duplicate rows in df4: 0

# %%
duplicates5 = df5.duplicated()

num_duplicates5 = duplicates5.sum()

print(f'Number of duplicate rows in df5: {num_duplicates5}')
# Out:
# Number of duplicate rows in df5: 0

# %%
# Assuming df1, df2, df3, df4, and df5 are your DataFrames

# Find the shape of each DataFrame
shape_df1 = df1.shape
shape_df2 = df2.shape
shape_df3 = df3.shape
shape_df4 = df4.shape
shape_df5 = df5.shape

# Print the shapes
print(f'Shape of df1: {shape_df1}')
print(f'Shape of df2: {shape_df2}')
print(f'Shape of df3: {shape_df3}')
print(f'Shape of df4: {shape_df4}')
print(f'Shape of df5: {shape_df5}')
# Out:
# Shape of df1: (1048575, 3)
# Shape of df2: (1048575, 3)
# Shape of df3: (1048575, 3)
# Shape of df4: (1048575, 3)
# Shape of df5: (1048575, 3)

# %%
import pandas as pd

# Concatenate all DataFrames vertically
merged_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# Display the merged DataFrame
print(merged_df)
# Out:
#         latitude  longitude  elevation
# 0        36.0000  -119.0000       2186
# 1        36.0000  -118.9997       2178
# 2        36.0000  -118.9994       2168
# 3        36.0000  -118.9992       2162
# 4        36.0000  -118.9989       2154
# ...          ...        ...        ...
# 5242870  36.0808  -119.8114        114
# 5242871  36.0808  -119.8111        114
# 5242872  36.0808  -119.8108        117
# 5242873  36.0808  -119.8106        117
# 5242874  36.0808  -119.8103        115
#
# [5242875 rows x 3 columns]

# %%
final_duplicates= merged_df.duplicated()

num_duplicates = final_duplicates.sum()

print(f'Number of duplicate rows in merged_df: {final_duplicates}')
# Out:
# Number of duplicate rows in merged_df: 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 5242870    False
# 5242871    False
# 5242872    False
# 5242873    False
# 5242874    False
# Length: 5242875, dtype: bool

# %%
# Assuming df1, df2, df3, df4, and df5 are your DataFrames

# Check the data types of all columns in each DataFrame
dtypes_df1 = df1.dtypes
dtypes_df2 = df2.dtypes
dtypes_df3 = df3.dtypes
dtypes_df4 = df4.dtypes
dtypes_df5 = df5.dtypes

# Print the data types
print(f'Data types of columns in df1:\n{dtypes_df1}\n')
print(f'Data types of columns in df2:\n{dtypes_df2}\n')
print(f'Data types of columns in df3:\n{dtypes_df3}\n')
print(f'Data types of columns in df4:\n{dtypes_df4}\n')
print(f'Data types of columns in df5:\n{dtypes_df5}\n')
# Out:
# Data types of columns in df1:
# latitude      object
# longitude    float64
# elevation      int64
# dtype: object
#
# Data types of columns in df2:
# latitude      object
# longitude    float64
# elevation      int64
# dtype: object
#
# Data types of columns in df3:
# latitude      object
# longitude    float64
# elevation      int64
# dtype: object
#
# Data types of columns in df4:
# latitude      object
# longitude    float64
# elevation      int64
# dtype: object
#
# Data types of columns in df5:
# latitude      object
# longitude    float64
# elevation      int64
# dtype: object

# %%
# import pandas as pd

# data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/merged_data.csv')
# data.head(20)

# %%
# Check the data types of all columns in each DataFrame
dtypes_merged_df = merged_df.dtypes
# Print the data types
print(f'Data types of columns in merged_df:\n{dtypes_merged_df}\n')
# Out:
# Data types of columns in merged_df:
# latitude      object
# longitude    float64
# elevation      int64
# dtype: object

# %%
import pandas as pd

merged_df['latitude'] = merged_df['latitude'].astype('float64')

# Check the data types to verify the change
print(merged_df.dtypes)
# Out:
# latitude     float64
# longitude    float64
# elevation      int64
# dtype: object

# %%
# Convert merged_df to CSV file
merged_df.to_csv('merged_data.csv', index=False)

print('DataFrame converted to CSV successfully!')
# Out:
# DataFrame converted to CSV successfully!

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D

# # Assuming df1 is your DataFrame with latitude, longitude, and elevation columns
# latitude = df1['latitude'].values
# longitude = df1['longitude'].values
# elevation = df1['elevation'].values

# # Downsample the data (e.g., select every nth value)
# n = 10  # Adjust n based on your desired level of downsampling
# latitude = latitude[::n]
# longitude = longitude[::n]
# elevation = elevation[::n]

# # 3D Surface Plot
# fig = plt.figure(figsize=(10, 8))
# ax = fig.add_subplot(111, projection='3d')
# X, Y = np.meshgrid(longitude, latitude)
# Z = elevation.reshape(X.shape)  # Reshape elevation to match X, Y grid shape
# ax.plot_surface(X, Y, Z, cmap='viridis')
# ax.set_xlabel('Longitude')
# ax.set_ylabel('Latitude')
# ax.set_zlabel('Elevation (m)')
# ax.set_title('3D Surface Plot of DEM Data from DataFrame')
# plt.show()
